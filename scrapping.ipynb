# %%
import requests
import json
import pandas as pd
import time

url = "https://igsyv1z1xi-dsn.algolia.net/1/indexes/*/queries"
headers = {
    "x-algolia-agent": "Algolia for JavaScript (5.0.0); Browser",
    "x-algolia-api-key": "6658746ce52e30dacfdd8ba5f8e8cf18",
    "x-algolia-application-id": "IGSYV1Z1XI",
    "content-type": "application/json"
}

payload = {
    "requests": [
        {
            "indexName": "product",
            "clickAnalytics": True,
            "facets": [
                "availability", "language", "learning_type", "level",
                "partner", "product", "program_type", "skills.skill", "subject"
            ],
            "hitsPerPage": 150,
            "page": 0,
            "query": ""
        }
    ]
}

all_courses = []
page = 0

total_pages = None

while True:
    print(f"[INFO] Fetching page {page}...")
    payload["requests"][0]["page"] = page
    response = requests.post(url, headers=headers, json=payload)
    data = response.json()

    hits = data["results"][0]["hits"]
    if total_pages is None:
        total_pages = data["results"][0].get("nbPages", 1)
        print(f"[INFO] Total pages available: {total_pages}")

    if not hits:
        break

    for course in hits:
        record = {
            "title": course.get("title", "Missing"),
            "partner": course.get("partner", ["Missing"]),
            "primary_description": course.get("primary_description", "Missing"),
            "secondary_description": course.get("secondary_description", "Missing"),
            "tertiary_description": course.get("tertiary_description", "Missing"),
            "availability": course.get("availability", ["Missing"]),
            "subject": course.get("subject", ["Missing"]),
            "level": course.get("level", ["Missing"]),
            "language": course.get("language", ["Missing"]),
            "product": course.get("product", "Missing"),
            "program_type": course.get("program_type", ["Missing"]),
            "staff": course.get("staff", ["Missing"]),
            "translation_language": course.get("ai_languages", {}).get("translation_languages", ["Missing"]),
            "transcription_language": course.get("ai_languages", {}).get("transcription_languages", ["Missing"]),
            "recent_enrollment_count": course.get("recent_enrollment_count", "Missing"),
            "marketing_url": course.get("marketing_url", "Missing"),
            "weeks_to_complete": course.get("weeks_to_complete", "Missing"),
            "skill": (
                [s["skill"] for s in course.get("skills", []) if isinstance(s, dict)]
                if isinstance(course.get("skills", []), list) else ["Missing"]
            )
        }
        all_courses.append(record)

    page += 1
    if page >= total_pages:
        break

    print(f"[INFO] Sleeping 10 seconds to respect crawl delay...")
    time.sleep(10)


df = pd.DataFrame(all_courses)
df.to_csv("edx_courses.csv", index=False)
print("[DONE] Saved to edx_courses.csv")
# Out:
# [INFO] Fetching page 0...
# [INFO] Total pages available: 7
# [INFO] Sleeping 10 seconds to respect crawl delay...
# [INFO] Fetching page 1...
# [INFO] Sleeping 10 seconds to respect crawl delay...
# [INFO] Fetching page 2...
# [INFO] Sleeping 10 seconds to respect crawl delay...
# [INFO] Fetching page 3...
# [INFO] Sleeping 10 seconds to respect crawl delay...
# [INFO] Fetching page 4...
# [INFO] Sleeping 10 seconds to respect crawl delay...
# [INFO] Fetching page 5...
# [INFO] Sleeping 10 seconds to respect crawl delay...
# [INFO] Fetching page 6...
# [DONE] Saved to edx_courses.csv

# %%
df = pd.read_csv("edx_courses.csv")
df
# Out:
#                                                  title  \
# 0                                  How to Learn Online
# 1                                    Corporate Finance
# 2                             The Science of Happiness
# 3                              Supply Chain Management
# 4                  Remote Work Revolution for Everyone
# ..                                                 ...
# 995            Eaux, villes et changements climatiques
# 996                  Fixed Income Portfolio Management
# 997                                  Artes na Educação
# 998  Strategic Communication for Sustainability Lea...
# 999  Critical Thinking: Fundamentals of Good Reasoning
#
#                                                partner  \
# 0                                              ['edX']
# 1                              ['Columbia University']
# 2               ['University of California, Berkeley']
# 3            ['Massachusetts Institute of Technology']
# 4                               ['Harvard University']
# ..                                                 ...
# 995                         ['Université de Montréal']
# 996                  ['New York Institute of Finance']
# 997         ['Fundação para a Ciência e a Tecnologia']
# 998  ['University of Maryland Center for Environmen...
# 999                                        ['IsraelX']
#
#                                    primary_description  \
# 0    <p>This course will prepare you with strategie...
# 1    Learn both the sound theoretical principles of...
# 2    <p>The first MOOC to teach positive psychology...
# 3    Earn a MicroMasters credential from MIT’s #1 r...
# 4    <p>In Remote Work Revolution for Everyone, you...
# ..                                                 ...
# 995  <p>Vous vous intéressez aux enjeux de l’eau en...
# 996  <p><span lang="EN-CA">Learn how to construct a...
# 997  <p>A Educação encontra-se num profundo process...
# 998  <p>Communicating science effectively is a crit...
# 999  <p>Learn the fundamentals of good reasoning, i...
#
#                                  secondary_description  \
# 0    <ul>\n<li>History, benefits, and foundational ...
# 1    <p>You will learn how to value a firm over the...
# 2    <ul>\n<li>What happiness really means and why ...
# 3    <p><img style="max-height:175px" align="right"...
# 4    <ul>\n<li>Understand the key elements of remot...
# ..                                                 ...
# 995  <p>Dans ce cours vous apprendrez à :</p>\n<p>•...
# 996  <ul>\n<li>Review of Fixed Income Concepts</li>...
# 997  <ul>\n<li>Identificar os principais contributo...
# 998  <ul>\r\n<li>How to identify and critique featu...
# 999  <p>● Arguments: What They Are and How to Recog...
#
#                                   tertiary_description  \
# 0    <p>This course harnesses science-backed techni...
# 1    Understand both the sound theoretical principl...
# 2    <p><em>"A free eight-week Science of Happiness...
# 3    To apply core methodologies (probability, stat...
# 4    <p>How are you thriving or surviving in your r...
# ..                                                 ...
# 995  <p>Vous avez à cœur la protection de l’eau? Vo...
# 996  <p>Fixed Income Portfolio Management is a comp...
# 997  <p>Sabemos que as gerações mais novas estão su...
# 998  <p>Effective science communicators are in shor...
# 999  <p>This course is an introduction to critical ...
#
#                                   availability  \
# 0                            ['Available now']
# 1                            ['Available now']
# 2                ['Upcoming', 'Available now']
# 3    ['Archived', 'Upcoming', 'Available now']
# 4                            ['Available now']
# ..                                         ...
# 995                          ['Available now']
# 996                          ['Available now']
# 997                          ['Available now']
# 998                          ['Available now']
# 999                          ['Available now']
#
#                                                subject  \
# 0                     ['Education & Teacher Training']
# 1     ['Business & Management', 'Economics & Finance']
# 2                                  ['Social Sciences']
# 3             ['Business & Management', 'Engineering']
# 4                            ['Business & Management']
# ..                                                 ...
# 995           ['Engineering', 'Environmental Studies']
# 996                            ['Economics & Finance']
# 997  ['Education & Teacher Training', 'Art & Culture']
# 998  ['Environmental Studies', 'Social Sciences', '...
# 999                            ['Philosophy & Ethics']
#
#                                             level        language  product  \
# 0                                ['Introductory']     ['English']   Course
# 1                                ['Introductory']     ['English']  Program
# 2                                ['Introductory']     ['English']   Course
# 3    ['Advanced', 'Introductory', 'Intermediate']     ['English']  Program
# 4                                ['Introductory']     ['English']   Course
# ..                                            ...             ...      ...
# 995                              ['Introductory']      ['French']   Course
# 996                                  ['Advanced']     ['English']   Course
# 997                              ['Introductory']  ['Portuguese']   Course
# 998                              ['Introductory']     ['English']   Course
# 999                              ['Introductory']     ['English']   Course
#
#                      program_type  \
# 0                              []
# 1    ['Professional Certificate']
# 2                              []
# 3                ['MicroMasters']
# 4    ['Professional Certificate']
# ..                            ...
# 995                            []
# 996  ['Professional Certificate']
# 997                            []
# 998  ['Professional Certificate']
# 999                            []
#
#                                                  staff  \
# 0                                                   []
# 1                                 ['daniel-wolfenzon']
# 2          ['dacher-keltner', 'emiliana-simon-thomas']
# 3    ['yossi-sheffi', 'james-blayney-rice-jr', 'jar...
# 4                                    ['tsedal-neeley']
# ..                                                 ...
# 995         ['louise-millette-2', 'veronique-gisondi']
# 996                    ['chris-thomas', 'jack-farmer']
# 997               ['teresa-eca', 'cesar-israel-paulo']
# 998        ['richard-arnold', 'william-bill-dennison']
# 999                                  ['jonathan-berg']
#
#                                   translation_language  \
# 0    ['Arabic', 'English', 'Spanish (Latin America)...
# 1                                                   []
# 2    ['Arabic', 'English', 'Spanish (Latin America)...
# 3                                                   []
# 4    ['Arabic', 'English', 'Spanish (Latin America)...
# ..                                                 ...
# 995                                                 []
# 996  ['Arabic', 'English', 'Spanish (Latin America)...
# 997  ['Arabic', 'English', 'Spanish (Latin America)...
# 998  ['Arabic', 'English', 'Spanish (Latin America)...
# 999  ['Arabic', 'English', 'Spanish (Latin America)...
#
#                                 transcription_language  \
# 0    ['Portuguese - Brazil', 'Indonesian', 'Arabic'...
# 1                                                   []
# 2    ['Russian', 'Indonesian', 'Spanish', 'Arabic',...
# 3                                                   []
# 4    ['Spanish', 'Arabic', 'Thai', 'Korean', 'Telug...
# ..                                                 ...
# 995                                                 []
# 996                                                 []
# 997                                                 []
# 998    ['Arabic', 'Portuguese - Brazil', 'Indonesian']
# 999                                                 []
#
#      recent_enrollment_count  \
# 0                      47714
# 1                      11648
# 2                      16821
# 3                      30033
# 4                      45954
# ..                       ...
# 995                      372
# 996                      371
# 997                      371
# 998                      371
# 999                      370
#
#                                          marketing_url  weeks_to_complete  \
# 0    https://www.edx.org/learn/how-to-learn/edx-how...                2.0
# 1    https://www.edx.org/certificates/professional-...                NaN
# 2    https://www.edx.org/learn/happiness/university...               11.0
# 3    https://www.edx.org/masters/micromasters/mitx-...                NaN
# 4    https://www.edx.org/learn/remote-work/harvard-...                3.0
# ..                                                 ...                ...
# 995  https://www.edx.org/learn/engineering/universi...                6.0
# 996  https://www.edx.org/learn/portfolio-management...                4.0
# 997  https://www.edx.org/learn/education-teacher-tr...                6.0
# 998  https://www.edx.org/learn/sustainability/unive...                5.0
# 999  https://www.edx.org/learn/critical-thinking-sk...               13.0
#
#                                                  skill
# 0                                  ['Learning Design']
# 1    ['Cost Of Capital', 'Finance', 'Investment Ban...
# 2    ['Empathy', 'Evolutionary Biology', 'Psychology']
# 3    ['Supply Chain Management', 'Innovation', 'Sup...
# 4    ['Telecommuting', 'Customer Relationship Build...
# ..                                                 ...
# 995                                                 []
# 996  ['Portfolio Management Professional', 'Portfol...
# 997                                                 []
# 998  ['Target Audience', 'Science Communication', '...
# 999           ['Critical Thinking', 'Decision Making']
#
# [1000 rows x 18 columns]
