# %%
import re
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
import pandas as pd
import nltk
nltk.download('wordnet')
nltk.download('stopwords')

stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()
stop_words = stopwords.words('english')

def lowering(text: str) -> str:
    text = text.lower()
    return text

def remove_punctuation_and_symbol(text: str) -> str:
    text = re.sub(r'[^\w\s]', '', text)
    return text

def stopword_removal(text: str) -> str:
    text = " ".join([word for word in text.split() if word not in stop_words])
    return text

# def stemming(text: str) -> str:
#     text = " ".join([stemmer.stem(word) for word in text.split()])
#     return text

def lemmatization(text: str) -> str:
    return " ".join([lemmatizer.lemmatize(word) for word in text.split()])

def remove_html_tags(text: str) -> str:
    text = re.sub(r'<[^>]+>', '', text)
    return text

def preprocessing(text: str) -> str:
    if not isinstance(text, str):
        return ""
    text = remove_html_tags(text)
    text = lowering(text)
    text = remove_punctuation_and_symbol(text)
    text = stopword_removal(text)
    text = lemmatization(text)
    return text
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv("scrape_result/edx_courses.csv")
df
# Out:
#                                                   title  \
# 0                                   How to Learn Online
# 1                              The Science of Happiness
# 2                   Remote Work Revolution for Everyone
# 3               CS50's Introduction to Computer Science
# 4     Data Visualization and Building Dashboards wit...
# ...                                                 ...
# 1651                               Corporate Innovation
# 1652                              IBM: Ciencia de datos
# 1653                         C++ Programming Essentials
# 1654                                  Marketing Digital
# 1655                            Blockchain Fundamentals
#
#                                      partner  \
# 0                                    ['edX']
# 1     ['University of California, Berkeley']
# 2                     ['Harvard University']
# 3                     ['Harvard University']
# 4                                    ['IBM']
# ...                                      ...
# 1651        ['The University of Queensland']
# 1652                                 ['IBM']
# 1653                                 ['IBM']
# 1654                 ['Universidad Galileo']
# 1655  ['University of California, Berkeley']
#
#                                     primary_description  \
# 0     This course will prepare you with strategies t...
# 1     The first MOOC to teach positive psychology. L...
# 2     In Remote Work Revolution for Everyone, you wi...
# 3     An introduction to the intellectual enterprise...
# 4     Build the fundamental knowledge necessary to u...
# ...                                                 ...
# 1651  Learn how to apply state-of-the-art methods to...
# 1652                                                NaN
# 1653  Become a skilled C++ developer who is fluent i...
# 1654  Aprende a conectar tu marca con el mundo. Cono...
# 1655  Harness the power of blockchain and cryptocurr...
#
#                                   secondary_description  \
# 0     \nHistory, benefits, and foundational concepts...
# 1     \nWhat happiness really means and why it matte...
# 2     \nUnderstand the key elements of remote work a...
# 3     \nA broad and robust understanding of computer...
# 4     \nDescribe the important role charts play in t...
# ...                                                 ...
# 1651  The ability to innovate is crucial for busines...
# 1652  La ciencia de datos y las habilidades de apren...
# 1653  This Professional Certificate program takes yo...
# 1654  Gana una ventaja competitiva convirtiéndote en...
# 1655  Developed by Blockchain at Berkeley and facult...
#
#                                    tertiary_description  \
# 0     This course harnesses science-backed technique...
# 1     "A free eight-week Science of Happiness course...
# 2     How are you thriving or surviving in your remo...
# 3     This is CS50x , Harvard University's introduct...
# 4     Please Note: Learners who successfully complet...
# ...                                                 ...
# 1651  Fundamentals of creative and design thinking t...
# 1652  Aplicar varias habilidades, técnicas y herrami...
# 1653  Fundamental concepts of programming using C++ ...
# 1654  Diseñar estrategias de marketing en redes soci...
# 1655  Synthesize your own blockchain solutions,Gain ...
#
#                        availability  \
# 0                 ['Available now']
# 1     ['Available now', 'Upcoming']
# 2                 ['Available now']
# 3                 ['Available now']
# 4                 ['Available now']
# ...                             ...
# 1651                   ['Archived']
# 1652                   ['Archived']
# 1653                   ['Archived']
# 1654                   ['Archived']
# 1655                   ['Archived']
#
#                                                 subject  \
# 0                      ['Education & Teacher Training']
# 1                                   ['Social Sciences']
# 2                             ['Business & Management']
# 3                   ['Computer Science', 'Engineering']
# 4                        ['Data Analysis & Statistics']
# ...                                                 ...
# 1651  ['Business & Management', 'Communication', 'Da...
# 1652  ['Data Analysis & Statistics', 'Computer Scien...
# 1653                               ['Computer Science']
# 1654         ['Communication', 'Business & Management']
# 1655                               ['Computer Science']
#
#                                  level     language  product  \
# 0                     ['Introductory']  ['English']   Course
# 1                     ['Introductory']  ['English']   Course
# 2                     ['Introductory']  ['English']   Course
# 3                     ['Introductory']  ['English']   Course
# 4                     ['Introductory']  ['English']   Course
# ...                                ...          ...      ...
# 1651                  ['Intermediate']  ['English']  Program
# 1652  ['Introductory', 'Intermediate']  ['Spanish']  Program
# 1653  ['Introductory', 'Intermediate']  ['English']  Program
# 1654                  ['Introductory']  ['Spanish']  Program
# 1655  ['Introductory', 'Intermediate']  ['English']  Program
#
#                                            program_type  \
# 0                                                    []
# 1                                                    []
# 2                          ['Professional Certificate']
# 3     ['Professional Certificate', 'Professional Cer...
# 4     ['Professional Certificate', 'Professional Cer...
# ...                                                 ...
# 1651                                   ['MicroMasters']
# 1652                       ['Professional Certificate']
# 1653                       ['Professional Certificate']
# 1654                       ['Professional Certificate']
# 1655                       ['Professional Certificate']
#
#                                                   staff  \
# 0                                                    []
# 1           ['emiliana-simon-thomas', 'dacher-keltner']
# 2                                     ['tsedal-neeley']
# 3           ['david-j-malan', 'brian-yu', 'doug-lloyd']
# 4                    ['sandip-sasha-joy', 'steve-ryan']
# ...                                                 ...
# 1651  ['martie-louise-verreynne', 'rachel-fitzgerald...
# 1652  ['romeo-kienzler', 'saeed-aghabozorgi', 'josep...
# 1653  ['nisha-p-2', 'sripriya-s', 'sathya-ponmalar-h...
# 1654  ['rocael-hernandez-ph-d', 'miguel-morales-ph-d...
# 1655  ['nadir-akhtar', 'rustie-lin', 'mengyi-gloria-...
#
#                                    translation_language  \
# 0     ['Arabic', 'English', 'Spanish (Latin America)...
# 1     ['Arabic', 'English', 'Spanish (Latin America)...
# 2     ['Arabic', 'English', 'Spanish (Latin America)...
# 3     ['Arabic', 'English', 'Spanish (Latin America)...
# 4     ['Arabic', 'English', 'Spanish (Latin America)...
# ...                                                 ...
# 1651                                                 []
# 1652                                                 []
# 1653                                                 []
# 1654                                                 []
# 1655                                                 []
#
#                                  transcription_language  \
# 0     ['Portuguese - Brazil', 'Indonesian', 'Arabic'...
# 1     ['Russian', 'Indonesian', 'Spanish', 'Portugue...
# 2     ['Spanish', 'Arabic', 'Thai', 'Korean', 'Chine...
# 3     ['Telugu', 'Turkish', 'Swahili', 'Arabic', 'Fr...
# 4      ['Russian', 'Portuguese - Brazil', 'Indonesian']
# ...                                                 ...
# 1651                                                 []
# 1652                                                 []
# 1653                                                 []
# 1654                                                 []
# 1655                                                 []
#
#       recent_enrollment_count  \
# 0                       47714
# 1                       16821
# 2                       45954
# 3                      425063
# 4                       11885
# ...                       ...
# 1651                     -269
# 1652                     -328
# 1653                     -444
# 1654                     -659
# 1655                     -971
#
#                                           marketing_url  weeks_to_complete  \
# 0     https://www.edx.org/learn/how-to-learn/edx-how...                2.0
# 1     https://www.edx.org/learn/happiness/university...               11.0
# 2     https://www.edx.org/learn/remote-work/harvard-...                3.0
# 3     https://www.edx.org/learn/computer-science/har...               12.0
# 4     https://www.edx.org/learn/data-visualization/i...                4.0
# ...                                                 ...                ...
# 1651  https://www.edx.org/masters/micromasters/uqx-c...                NaN
# 1652  https://www.edx.org/certificates/professional-...                NaN
# 1653  https://www.edx.org/certificates/professional-...                NaN
# 1654  https://www.edx.org/certificates/professional-...                NaN
# 1655  https://www.edx.org/certificates/professional-...                NaN
#
#                                                   skill
# 0                                   ['Learning Design']
# 1     ['Empathy', 'Evolutionary Biology', 'Psychology']
# 2     ['Telecommuting', 'Customer Relationship Build...
# 3     ['Cryptography', 'Resource Management', 'Algor...
# 4     ['Data Visualization', 'Data Analysis', 'Micro...
# ...                                                 ...
# 1651                                                 []
# 1652  ['Data Science', 'Python (Programming Language...
# 1653  ['Object-Oriented Programming (OOP)', 'C++ (Pr...
# 1654  ['Digital Marketing', 'Advertising Campaigns',...
# 1655  ['Blockchain', 'Planning', 'Proofreading', 'Bi...
#
# [1656 rows x 18 columns]

# %%
exclude_cols = [
    'marketing_url', 'availability', 'subject', 'level', 'product', 'program_type',
    'staff', 'translation_language', 'transcription_language', 'partner'
]

for col in df.columns:
    if df[col].dtype == 'object' and col not in exclude_cols:
        df[col] = df[col].apply(preprocessing)
        df[col] = df[col].replace("", None)

# %%
df
# Out:
#                                                   title  \
# 0                                          learn online
# 1                                     science happiness
# 2                       remote work revolution everyone
# 3                   cs50s introduction computer science
# 4     data visualization building dashboard excel co...
# ...                                                 ...
# 1651                               corporate innovation
# 1652                               ibm ciencia de datos
# 1653                            c programming essential
# 1654                                  marketing digital
# 1655                             blockchain fundamental
#
#                                      partner  \
# 0                                    ['edX']
# 1     ['University of California, Berkeley']
# 2                     ['Harvard University']
# 3                     ['Harvard University']
# 4                                    ['IBM']
# ...                                      ...
# 1651        ['The University of Queensland']
# 1652                                 ['IBM']
# 1653                                 ['IBM']
# 1654                 ['Universidad Galileo']
# 1655  ['University of California, Berkeley']
#
#                                     primary_description  \
# 0     course prepare strategy successful online lear...
# 1     first mooc teach positive psychology learn sci...
# 2     remote work revolution everyone learn excel vi...
# 3     introduction intellectual enterprise computer ...
# 4     build fundamental knowledge necessary use exce...
# ...                                                 ...
# 1651  learn apply stateoftheart method foster innova...
# 1652                                               None
# 1653  become skilled c developer fluent complete syn...
# 1654  aprende conectar tu marca con el mundo conoce ...
# 1655  harness power blockchain cryptocurrencies deve...
#
#                                   secondary_description  \
# 0     history benefit foundational concept online le...
# 1     happiness really mean matter increase happines...
# 2     understand key element remote work use knowled...
# 3     broad robust understanding computer science pr...
# 4     describe important role chart play telling dat...
# ...                                                 ...
# 1651  ability innovate crucial business survival gro...
# 1652  la ciencia de datos la habilidades de aprendiz...
# 1653  professional certificate program take right fu...
# 1654  gana una ventaja competitiva convirtiéndote en...
# 1655  developed blockchain berkeley faculty uc berke...
#
#                                    tertiary_description  \
# 0     course harness sciencebacked technique applica...
# 1     free eightweek science happiness course offer ...
# 2     thriving surviving remote work environment rem...
# 3     cs50x harvard university introduction intellec...
# 4     please note learner successfully complete ibm ...
# ...                                                 ...
# 1651  fundamental creative design thinking enable in...
# 1652  aplicar varias habilidades técnicas herramient...
# 1653  fundamental concept programming using c includ...
# 1654  diseñar estrategias de marketing en redes soci...
# 1655  synthesize blockchain solutionsgain indepth un...
#
#                        availability  \
# 0                 ['Available now']
# 1     ['Available now', 'Upcoming']
# 2                 ['Available now']
# 3                 ['Available now']
# 4                 ['Available now']
# ...                             ...
# 1651                   ['Archived']
# 1652                   ['Archived']
# 1653                   ['Archived']
# 1654                   ['Archived']
# 1655                   ['Archived']
#
#                                                 subject  \
# 0                      ['Education & Teacher Training']
# 1                                   ['Social Sciences']
# 2                             ['Business & Management']
# 3                   ['Computer Science', 'Engineering']
# 4                        ['Data Analysis & Statistics']
# ...                                                 ...
# 1651  ['Business & Management', 'Communication', 'Da...
# 1652  ['Data Analysis & Statistics', 'Computer Scien...
# 1653                               ['Computer Science']
# 1654         ['Communication', 'Business & Management']
# 1655                               ['Computer Science']
#
#                                  level language  product  \
# 0                     ['Introductory']  english   Course
# 1                     ['Introductory']  english   Course
# 2                     ['Introductory']  english   Course
# 3                     ['Introductory']  english   Course
# 4                     ['Introductory']  english   Course
# ...                                ...      ...      ...
# 1651                  ['Intermediate']  english  Program
# 1652  ['Introductory', 'Intermediate']  spanish  Program
# 1653  ['Introductory', 'Intermediate']  english  Program
# 1654                  ['Introductory']  spanish  Program
# 1655  ['Introductory', 'Intermediate']  english  Program
#
#                                            program_type  \
# 0                                                    []
# 1                                                    []
# 2                          ['Professional Certificate']
# 3     ['Professional Certificate', 'Professional Cer...
# 4     ['Professional Certificate', 'Professional Cer...
# ...                                                 ...
# 1651                                   ['MicroMasters']
# 1652                       ['Professional Certificate']
# 1653                       ['Professional Certificate']
# 1654                       ['Professional Certificate']
# 1655                       ['Professional Certificate']
#
#                                                   staff  \
# 0                                                    []
# 1           ['emiliana-simon-thomas', 'dacher-keltner']
# 2                                     ['tsedal-neeley']
# 3           ['david-j-malan', 'brian-yu', 'doug-lloyd']
# 4                    ['sandip-sasha-joy', 'steve-ryan']
# ...                                                 ...
# 1651  ['martie-louise-verreynne', 'rachel-fitzgerald...
# 1652  ['romeo-kienzler', 'saeed-aghabozorgi', 'josep...
# 1653  ['nisha-p-2', 'sripriya-s', 'sathya-ponmalar-h...
# 1654  ['rocael-hernandez-ph-d', 'miguel-morales-ph-d...
# 1655  ['nadir-akhtar', 'rustie-lin', 'mengyi-gloria-...
#
#                                    translation_language  \
# 0     ['Arabic', 'English', 'Spanish (Latin America)...
# 1     ['Arabic', 'English', 'Spanish (Latin America)...
# 2     ['Arabic', 'English', 'Spanish (Latin America)...
# 3     ['Arabic', 'English', 'Spanish (Latin America)...
# 4     ['Arabic', 'English', 'Spanish (Latin America)...
# ...                                                 ...
# 1651                                                 []
# 1652                                                 []
# 1653                                                 []
# 1654                                                 []
# 1655                                                 []
#
#                                  transcription_language  \
# 0     ['Portuguese - Brazil', 'Indonesian', 'Arabic'...
# 1     ['Russian', 'Indonesian', 'Spanish', 'Portugue...
# 2     ['Spanish', 'Arabic', 'Thai', 'Korean', 'Chine...
# 3     ['Telugu', 'Turkish', 'Swahili', 'Arabic', 'Fr...
# 4      ['Russian', 'Portuguese - Brazil', 'Indonesian']
# ...                                                 ...
# 1651                                                 []
# 1652                                                 []
# 1653                                                 []
# 1654                                                 []
# 1655                                                 []
#
#       recent_enrollment_count  \
# 0                       47714
# 1                       16821
# 2                       45954
# 3                      425063
# 4                       11885
# ...                       ...
# 1651                     -269
# 1652                     -328
# 1653                     -444
# 1654                     -659
# 1655                     -971
#
#                                           marketing_url  weeks_to_complete  \
# 0     https://www.edx.org/learn/how-to-learn/edx-how...                2.0
# 1     https://www.edx.org/learn/happiness/university...               11.0
# 2     https://www.edx.org/learn/remote-work/harvard-...                3.0
# 3     https://www.edx.org/learn/computer-science/har...               12.0
# 4     https://www.edx.org/learn/data-visualization/i...                4.0
# ...                                                 ...                ...
# 1651  https://www.edx.org/masters/micromasters/uqx-c...                NaN
# 1652  https://www.edx.org/certificates/professional-...                NaN
# 1653  https://www.edx.org/certificates/professional-...                NaN
# 1654  https://www.edx.org/certificates/professional-...                NaN
# 1655  https://www.edx.org/certificates/professional-...                NaN
#
#                                                   skill
# 0                                       learning design
# 1               empathy evolutionary biology psychology
# 2          telecommuting customer relationship building
# 3     cryptography resource management algorithm pyt...
# 4     data visualization data analysis microsoft exc...
# ...                                                 ...
# 1651                                               None
# 1652  data science python programming language machi...
# 1653  objectoriented programming oop c programming l...
# 1654  digital marketing advertising campaign marketi...
# 1655  blockchain planning proofreading bitcoin crypt...
#
# [1656 rows x 18 columns]

# %%
import ast

list_cols = [
    'availability', 'subject', 'level', 'program_type',
    'staff', 'translation_language', 'transcription_language', 'partner'
]

for col in list_cols:
    if col in df.columns:
        df[col] = df[col].apply(
            lambda x: (
                ', '.join(ast.literal_eval(x)) if isinstance(x, str) and x.startswith('[') and x.strip() != "[]" else
                None if x == "" or x == "[]" else
                x
            )
        )
        df[col] = df[col].str.lower()
        
df
# Out:
#                                                   title  \
# 0                                          learn online
# 1                                     science happiness
# 2                       remote work revolution everyone
# 3                   cs50s introduction computer science
# 4     data visualization building dashboard excel co...
# ...                                                 ...
# 1651                               corporate innovation
# 1652                               ibm ciencia de datos
# 1653                            c programming essential
# 1654                                  marketing digital
# 1655                             blockchain fundamental
#
#                                  partner  \
# 0                                    edx
# 1     university of california, berkeley
# 2                     harvard university
# 3                     harvard university
# 4                                    ibm
# ...                                  ...
# 1651        the university of queensland
# 1652                                 ibm
# 1653                                 ibm
# 1654                 universidad galileo
# 1655  university of california, berkeley
#
#                                     primary_description  \
# 0     course prepare strategy successful online lear...
# 1     first mooc teach positive psychology learn sci...
# 2     remote work revolution everyone learn excel vi...
# 3     introduction intellectual enterprise computer ...
# 4     build fundamental knowledge necessary use exce...
# ...                                                 ...
# 1651  learn apply stateoftheart method foster innova...
# 1652                                               None
# 1653  become skilled c developer fluent complete syn...
# 1654  aprende conectar tu marca con el mundo conoce ...
# 1655  harness power blockchain cryptocurrencies deve...
#
#                                   secondary_description  \
# 0     history benefit foundational concept online le...
# 1     happiness really mean matter increase happines...
# 2     understand key element remote work use knowled...
# 3     broad robust understanding computer science pr...
# 4     describe important role chart play telling dat...
# ...                                                 ...
# 1651  ability innovate crucial business survival gro...
# 1652  la ciencia de datos la habilidades de aprendiz...
# 1653  professional certificate program take right fu...
# 1654  gana una ventaja competitiva convirtiéndote en...
# 1655  developed blockchain berkeley faculty uc berke...
#
#                                    tertiary_description  \
# 0     course harness sciencebacked technique applica...
# 1     free eightweek science happiness course offer ...
# 2     thriving surviving remote work environment rem...
# 3     cs50x harvard university introduction intellec...
# 4     please note learner successfully complete ibm ...
# ...                                                 ...
# 1651  fundamental creative design thinking enable in...
# 1652  aplicar varias habilidades técnicas herramient...
# 1653  fundamental concept programming using c includ...
# 1654  diseñar estrategias de marketing en redes soci...
# 1655  synthesize blockchain solutionsgain indepth un...
#
#                  availability  \
# 0               available now
# 1     available now, upcoming
# 2               available now
# 3               available now
# 4               available now
# ...                       ...
# 1651                 archived
# 1652                 archived
# 1653                 archived
# 1654                 archived
# 1655                 archived
#
#                                                 subject  \
# 0                          education & teacher training
# 1                                       social sciences
# 2                                 business & management
# 3                         computer science, engineering
# 4                            data analysis & statistics
# ...                                                 ...
# 1651  business & management, communication, data ana...
# 1652  data analysis & statistics, computer science, ...
# 1653                                   computer science
# 1654               communication, business & management
# 1655                                   computer science
#
#                            level language  product  \
# 0                   introductory  english   Course
# 1                   introductory  english   Course
# 2                   introductory  english   Course
# 3                   introductory  english   Course
# 4                   introductory  english   Course
# ...                          ...      ...      ...
# 1651                intermediate  english  Program
# 1652  introductory, intermediate  spanish  Program
# 1653  introductory, intermediate  english  Program
# 1654                introductory  spanish  Program
# 1655  introductory, intermediate  english  Program
#
#                                            program_type  \
# 0                                                  None
# 1                                                  None
# 2                              professional certificate
# 3     professional certificate, professional certifi...
# 4     professional certificate, professional certifi...
# ...                                                 ...
# 1651                                       micromasters
# 1652                           professional certificate
# 1653                           professional certificate
# 1654                           professional certificate
# 1655                           professional certificate
#
#                                                   staff  \
# 0                                                  None
# 1                 emiliana-simon-thomas, dacher-keltner
# 2                                         tsedal-neeley
# 3                   david-j-malan, brian-yu, doug-lloyd
# 4                          sandip-sasha-joy, steve-ryan
# ...                                                 ...
# 1651  martie-louise-verreynne, rachel-fitzgerald, ti...
# 1652  romeo-kienzler, saeed-aghabozorgi, joseph-sant...
# 1653  nisha-p-2, sripriya-s, sathya-ponmalar-h, abin...
# 1654  rocael-hernandez-ph-d, miguel-morales-ph-d, jo...
# 1655       nadir-akhtar, rustie-lin, mengyi-gloria-wang
#
#                                    translation_language  \
# 0     arabic, english, spanish (latin america), indo...
# 1     arabic, english, spanish (latin america), indo...
# 2     arabic, english, spanish (latin america), indo...
# 3     arabic, english, spanish (latin america), indo...
# 4     arabic, english, spanish (latin america), indo...
# ...                                                 ...
# 1651                                               None
# 1652                                               None
# 1653                                               None
# 1654                                               None
# 1655                                               None
#
#                                  transcription_language  \
# 0      portuguese - brazil, indonesian, arabic, spanish
# 1     russian, indonesian, spanish, portuguese - bra...
# 2     spanish, arabic, thai, korean, chinese - china...
# 3     telugu, turkish, swahili, arabic, french, germ...
# 4              russian, portuguese - brazil, indonesian
# ...                                                 ...
# 1651                                               None
# 1652                                               None
# 1653                                               None
# 1654                                               None
# 1655                                               None
#
#       recent_enrollment_count  \
# 0                       47714
# 1                       16821
# 2                       45954
# 3                      425063
# 4                       11885
# ...                       ...
# 1651                     -269
# 1652                     -328
# 1653                     -444
# 1654                     -659
# 1655                     -971
#
#                                           marketing_url  weeks_to_complete  \
# 0     https://www.edx.org/learn/how-to-learn/edx-how...                2.0
# 1     https://www.edx.org/learn/happiness/university...               11.0
# 2     https://www.edx.org/learn/remote-work/harvard-...                3.0
# 3     https://www.edx.org/learn/computer-science/har...               12.0
# 4     https://www.edx.org/learn/data-visualization/i...                4.0
# ...                                                 ...                ...
# 1651  https://www.edx.org/masters/micromasters/uqx-c...                NaN
# 1652  https://www.edx.org/certificates/professional-...                NaN
# 1653  https://www.edx.org/certificates/professional-...                NaN
# 1654  https://www.edx.org/certificates/professional-...                NaN
# 1655  https://www.edx.org/certificates/professional-...                NaN
#
#                                                   skill
# 0                                       learning design
# 1               empathy evolutionary biology psychology
# 2          telecommuting customer relationship building
# 3     cryptography resource management algorithm pyt...
# 4     data visualization data analysis microsoft exc...
# ...                                                 ...
# 1651                                               None
# 1652  data science python programming language machi...
# 1653  objectoriented programming oop c programming l...
# 1654  digital marketing advertising campaign marketi...
# 1655  blockchain planning proofreading bitcoin crypt...
#
# [1656 rows x 18 columns]

# %%
df.isnull().sum()
# Out:
# title                         0
# partner                       0
# primary_description         145
# secondary_description         3
# tertiary_description          6
# availability                  0
# subject                       2
# level                         3
# language                      3
# product                       0
# program_type                401
# staff                        97
# translation_language        887
# transcription_language     1044
# recent_enrollment_count       0
# marketing_url                 0
# weeks_to_complete           657
# skill                       191
# dtype: int64

# %%
df['text'] = df['title'] + " " + df['primary_description'] + " " + df['secondary_description'] + " " + df['tertiary_description'] + " " + df['subject'] + " " + df['skill']
df['text'] = df['text'].map(lambda x: str(x).replace(", ", ''))
df['text'] = df['text'].fillna('').astype(str)
df.to_csv('preprocessed/edx_courses.csv', index=False)

# %% [markdown]
# # LinkedIn

# %%
job_df = pd.read_csv("scrape_result/linkedin_jobs.csv")
job_df.columns
# Out:
# Index(['job_link', 'job_title', 'company_name', 'location', 'responsibilities',
#        'requirements', 'level', 'employment_type', 'job_function',
#        'industries', 'time_posted', 'num_applicants'],
#       dtype='object')

# %%
processed_cols = ['job_title', 'responsibilities', 'requirements', 'job_function', 'industries']
job_df[processed_cols]
# Out:
#                                         job_title  \
# 0                       General Affair Internship
# 1                             Data Analyst Intern
# 2                   Project Management Internship
# 3     Improvement Campaign & Communication Intern
# 4                              Management Trainee
# ...                                           ...
# 4505                Koordinator TH (Kuta Selatan)
# 4506                             Business Analyst
# 4507                    Housekeepping Coordinator
# 4508                Préventeur Santé Sécurité H/F
# 4509                        Marketing Coordinator
#
#                                        responsibilities  \
# 0     ['Membuat konten kreatif (foto, video, caption...
# 1     ['Understand the day-to-day issues that our bu...
# 2     ['Assist in compiling & updating the project t...
# 3     ['Melaksanakan observasi lapangan dan pencatat...
# 4     ['Gelar sarjana dari jurusan apa pun', 'Lulusa...
# ...                                                 ...
# 4505  ['Membuat Plan Schedule Shifting untuk team Tr...
# 4506  ['Acts as a bridge between the business proble...
# 4507                                                NaN
# 4508  ['Soutenir les équipes de proximité dans la pr...
# 4509  ['You will influence & contribute to “Building...
#
#                                            requirements  \
# 0     ['Mahasiswa aktif dari jurusan Komunikasi, Man...
# 1     ['Student of Bachelor degree in Statistics or ...
# 2     ['Willing to be placed in Kalbe Morinaga Cikam...
# 3     ['Mendukung pelaksanaan event TPM dan campaign...
# 4                                                   NaN
# ...                                                 ...
# 4505  ['Laki-laki/Perempuan', 'Usia min 21 tahun', '...
# 4506  ['Demonstrated understanding of business pract...
# 4507                                                NaN
# 4508  ['Avoir un poste basé à Nantes et profiter de ...
# 4509  ['Create visualizations that convey accurate m...
#
#                                          job_function  \
# 0       Other, Information Technology, and Management
# 1     Information Technology and Business Development
# 2       Project Management and Information Technology
# 3                                 Marketing and Sales
# 4                              Education and Training
# ...                                               ...
# 4505                                            Other
# 4506    Research, Analyst, and Information Technology
# 4507                     Management and Manufacturing
# 4508                     Management and Manufacturing
# 4509                                        Marketing
#
#                                              industries
# 0                            Food and Beverage Services
# 1                                                Retail
# 2                            Food and Beverage Services
# 3                            Food and Beverage Services
# 4                    Automation Machinery Manufacturing
# ...                                                 ...
# 4505                                Internet Publishing
# 4506                      IT Services and IT Consulting
# 4507                                        Hospitality
# 4508                            Machinery Manufacturing
# 4509  Travel Arrangements, Hospitality, and Airlines...
#
# [4510 rows x 5 columns]

# %%
from translate import Translator
from langdetect import detect
import ast 

t = Translator(from_lang='id', to_lang='en')

for index, row in job_df.iterrows():
    if row['responsibilities'] is None or row['responsibilities'] == 'nan' or pd.isna(row['responsibilities']):
        continue
    responsibilities = ast.literal_eval(row['responsibilities'])
    for index, res in enumerate(responsibilities):
        if res != None and res.strip() != "":
            try:
                lang = detect(res)
            except Exception as e:
                print(f"Language detection error for {res}: {e}")
                continue
            if lang != 'en':
                try:
                    responsibilities[index] = t.translate(res)
                except Exception as e:
                    print(f"Translation error for {res}: {e}")
                    responsibilities[index] = res
    job_df.loc[index, ['responsibilities'] ]= str(responsibilities)
    if row['requirements'] is None or row['requirements'] == 'nan' or pd.isna(row['requirements']):
        continue
    requirements = ast.literal_eval(row['requirements'])
    for index, req in enumerate(requirements):
        if req != None and req.strip() != "":
            try:
                lang = detect(res)
            except Exception as e:
                print(f"Language detection error for {req}: {e}")
                continue
            if lang != 'en':
                try:
                    requirements[index] = t.translate(req)
                except Exception as e:
                    print(f"Translation error for {req}: {e}")
                    requirements[index] = req
    job_df.loc[index, ['requirements']] = str(requirements)
# Out:
# Language detection error for https://argus.gg: No features in text.
# Language detection error for https://world.dev: No features in text.
# Language detection error for https://twitter.com/ArgusLabs_: No features in text.
# Language detection error for Final-year university students or fresh graduates in Computer Science, Game Development, or a related field.: No features in text.
# Language detection error for Proficiency in Go.: No features in text.
# Language detection error for Knowledge of game server frameworks like Agones or Nakama.: No features in text.
# Language detection error for Passionate individuals eager to explore the gaming and Web3 industries.: No features in text.
# Language detection error for A willingness to learn, collaborate, and contribute to real-world projects.: No features in text.
# Language detection error for A proactive mindset and a commitment to excellence.: No features in text.
# Language detection error for https://argus.gg: No features in text.
# Language detection error for https://world.dev: No features in text.
# Language detection error for https://twitter.com/ArgusLabs_: No features in text.
# Language detection error for Final-year university students or fresh graduates from any discipline.: No features in text.
# Language detection error for Passionate individuals eager to explore the gaming and Web3 industries.: No features in text.
# Language detection error for A willingness to learn, collaborate, and contribute to real-world projects.: No features in text.
# Language detection error for A proactive mindset and a commitment to excellence.: No features in text.
# Translation error for Pengalaman dalam manajemen aset (aset kantor/tetap) dan manajemen fasilitas: HTTPSConnectionPool(host='api.mymemory.translated.net', port=443): Read timed out. (read timeout=None)
# Translation error for Mahir menggunakan Excel dan rumus umum.: HTTPConnectionPool(host='api.mymemory.translated.net', port=80): Max retries exceeded with url: /get?q=Mahir+menggunakan+Excel+dan+rumus+umum.&langpair=id%7Cen (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x00000254C659F4A0>: Failed to establish a new connection: [WinError 10051] A socket operation was attempted to an unreachable network'))
# Translation error for Kemampuan komunikasi, interpersonal, dan berpikir analitis yang baik: HTTPConnectionPool(host='api.mymemory.translated.net', port=80): Max retries exceeded with url: /get?q=Kemampuan+komunikasi%2C+interpersonal%2C+dan+berpikir+analitis+yang+baik&langpair=id%7Cen (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x00000254C659FBF0>: Failed to resolve 'api.mymemory.translated.net' (Name or service not known: api.mymemory.translated.net using 1 resolver(s))"))
# Translation error for Kemampuan untuk menyimpan catatan aset yang akurat dengan perhatian yang tinggi terhadap detailKomunikasi dua arah yang efektif dengan rekan kerja, pihak internal, dan eksternal: HTTPConnectionPool(host='api.mymemory.translated.net', port=80): Max retries exceeded with url: /get?q=Kemampuan+untuk+menyimpan+catatan+aset+yang+akurat+dengan+perhatian+yang+tinggi+terhadap+detailKomunikasi+dua+arah+yang+efektif+dengan+rekan+kerja%2C+pihak+internal%2C+dan+eksternal&langpair=id%7Cen (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x00000254BFF65460>: Failed to resolve 'api.mymemory.translated.net' (Name or service not known: api.mymemory.translated.net using 1 resolver(s))"))
# Translation error for Monitoring aktivitas pelayanan General Affair untuk seluruh Departemen yang membutuhkan: HTTPConnectionPool(host='api.mymemory.translated.net', port=80): Max retries exceeded with url: /get?q=Monitoring+aktivitas+pelayanan+General+Affair+untuk+seluruh+Departemen+yang+membutuhkan&langpair=id%7Cen (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x00000254AE02BE90>: Failed to resolve 'api.mymemory.translated.net' (Name or service not known: api.mymemory.translated.net using 1 resolver(s))"))
# Translation error for Memastikan aset kantor tercatat secara akurat sesuai dengan kelas asetnya: HTTPConnectionPool(host='api.mymemory.translated.net', port=80): Max retries exceeded with url: /get?q=Memastikan+aset+kantor+tercatat+secara+akurat+sesuai+dengan+kelas+asetnya&langpair=id%7Cen (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x00000254C662DC40>: Failed to resolve 'api.mymemory.translated.net' (Name or service not known: api.mymemory.translated.net using 1 resolver(s))"))
# Translation error for Mendaftarkan semua aset kantor secara manual dan lakukan pemeriksaan stok opname berdasarkan lokasi aset: HTTPConnectionPool(host='api.mymemory.translated.net', port=80): Max retries exceeded with url: /get?q=Mendaftarkan+semua+aset+kantor+secara+manual+dan+lakukan+pemeriksaan+stok+opname+berdasarkan+lokasi+aset&langpair=id%7Cen (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x00000254C1598710>: Failed to resolve 'api.mymemory.translated.net' (Name or service not known: api.mymemory.translated.net using 1 resolver(s))"))
# Translation error for Membuat kode aset, aplikasi/memo internal untuk aset kantor yang akan dibuang atau hilang: HTTPConnectionPool(host='api.mymemory.translated.net', port=80): Max retries exceeded with url: /get?q=Membuat+kode+aset%2C+aplikasi%2Fmemo+internal+untuk+aset+kantor+yang+akan+dibuang+atau+hilang&langpair=id%7Cen (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x00000254C65915E0>: Failed to resolve 'api.mymemory.translated.net' (Name or service not known: api.mymemory.translated.net using 1 resolver(s))"))
# Translation error for Mengelola / mengawasi fasilitas gedung, perawatan, dan memperhatikan lingkungan kerja kantor dan fasilitas kantor: HTTPConnectionPool(host='api.mymemory.translated.net', port=80): Max retries exceeded with url: /get?q
HTTPConnectionPool(host='api.mymemory.translated.net', port=80): Max retries exceeded with url: /get?q=Stakeholder+Relations%3A+Interface+with+Gentem+Group+C-suite%2C+manage+investor+relations%2C+and+represent+brand+at+national+industry+events&langpair=id%7Cen (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x00000254C66241A0>: Failed to resolve 'api.mymemory.translated.net' (Name or service not known: api.mymemory.translated.net using 1 resolver(s))"))
# Translation error for Avantages Groupe : 13ème mois, CSE, tickets restaurant, actionnariat du Groupe, primes de participation et d’intéressement, RTT: HTTPConnectionPool(host='api.mymemory.translated.net', port=80): Max retries exceeded with url: /get?q=Avantages+Groupe+%3A+13%C3%A8me+mois%2C+CSE%2C+tickets+restaurant%2C+actionnariat+du+Groupe%2C+primes+de+participation+et+d%E2%80%99int%C3%A9ressement%2C+RTT&langpair=id%7Cen (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x00000254C6EF89E0>: Failed to resolve 'api.mymemory.translated.net' (Name or service not known: api.mymemory.translated.net using 1 resolver(s))"))
# Translation error for Accompagnement tout au long du parcours professionnel et projet de carrière au sein du Groupe: HTTPConnectionPool(host='api.mymemory.translated.net', port=80): Max retries exceeded with url: /get?q=Accompagnement+tout+au+long+du+parcours+professionnel+et+projet+de+carri%C3%A8re+au+sein+du+Groupe&langpair=id%7Cen (Caused by NameResolutionError("<urllib3.connection.HTTPConnection object at 0x00000254C6592690>: Failed to resolve 'api.mymemory.translated.net' (Name or service not known: api.mymemory.translated.net using 1 resolver(s))"))
# Language detection error for https://www.youtube.com/watch?v=CTrEqJgytVA: No features in text.
# Language detection error for Vous aimez travailler en extérieur et n’avez pas peur de la hauteur ;: No features in text.
# Language detection error for Vous souhaitez réaliser votre année de Terminale Bac Pro MELEC, en alternance ;: No features in text.
# Language detection error for Vous avez déjà un CAP ou un Bac Pro en Électricité et vous souhaitez préparer un Titre Professionnel ou une Mention Complémentaire de Monteur de Réseaux Électriques Aéro-souterrains ;: No features in text.
# Language detection error for Vous possédez le permis B.: No features in text.
# Language detection error for https://www.youtube.com/watch?v=CTrEqJgytVA: No features in text.
# Language detection error for Vous aimez travailler en extérieur et n’avez pas peur de la hauteur ;: No features in text.
# Language detection error for Vous souhaitez réaliser votre année de Terminale Bac Pro MELEC, en alternance ;: No features in text.
# Language detection error for Vous avez déjà un CAP ou un Bac Pro en Électricité et vous souhaitez préparer un Titre Professionnel ou une Mention Complémentaire de Monteur de Réseaux Électriques Aéro-souterrains ;: No features in text.
# Language detection error for Vous possédez le permis B.: No features in text.
# Language detection error for https://www.youtube.com/watch?v=CTrEqJgytVA: No features in text.
# Language detection error for Vous aimez travailler en extérieur: No features in text.
# Language detection error for Vous avez la capacité à travailler en hauteur: No features in text.
# Language detection error for Vous avez des connaissances en électricité ou avez un diplôme en électricité: No features in text.
# Language detection error for Vous souhaitez préparer un Titre Professionnel Monteur de réseaux ou une Mention Complémentaire de Monteur de Réseaux Électriques aéro-souterrains: No features in text.
# Language detection error for Vous possédez le permis B.: No features in text.
# Language detection error for https://www.youtube.com/watch?v=CTrEqJgytVA: No features in text.
# Language detection error for Vous aimez travailler en extérieur: No features in text.
# Language detection error for Vous avez la capacité à travailler en hauteur: No features in text.
# Language detection error for Vous avez des connaissances en électricité ou avez un diplôme en électricité: No features in text.
# Language detection error for Vous souhaitez préparer un Titre Professionnel Monteur de réseaux ou une Mention Complémentaire de Monteur de Réseaux Électriques aéro-souterrains: No features in text.
# Language detection error for Vous possédez le permis B.: No features in text.
# Language detection error for https://www.youtube.com/watch?v=CTrEqJgytVA: No features in text.
# Language detection error for Vous aimez travailler en extérieur: No features in text.
# Language detection error for Vous avez la capacité à travailler en hauteur: No features in text.
# Language detection error for Vous avez des connaissances en électricité ou avez un diplôme en électricité: No features in text.
# Language detection error for Vous souhaitez préparer un Titre Professionnel Monteur de réseaux ou une Mention Complémentaire de Monteur de Réseaux Électriques aéro-souterrains: No features in text.
# Language detection error for Vous possédez le permis B.: No features in text.
# Language detection error for https://www.youtube.com/watch?v=CTrEqJgytVA: No features in text.
# Language detection error for Vous aimez travailler en extérieur et n’avez pas peur de la hauteur ;: No features in text.
# Language detection error for Vous souhaitez réaliser votre année de Terminale Bac Pro MELEC, en alternance ;: No features in text.
# Language detection error for Vous avez déjà un CAP ou un Bac Pro en Électricité et vous souhaitez préparer un Titre Professionnel ou une Mention Complémentaire de Monteur de Réseaux Électriques Aéro-souterrains ;: No features in text.
# Language detection error for Vous possédez le permis B.: No features in text.
# Language detection error for https://www.youtube.com/watch?v=CTrEqJgytVA: No features in text.
# Language detection error for Vous aimez travailler en extérieur: No features in text.
# Language detection error for Vous avez la capacité à travailler en hauteur: No features in text.
# Language detection error for Vous avez des connaissances en électricité ou avez un diplôme en électricité: No features in text.
# Language detection error for Vous souhaitez préparer un Titre Professionnel Monteur de réseaux ou une Mention Complémentaire de Monteur de Réseaux Électriques aéro-souterrains: No features in text.
# Language detection error for Vous possédez le permis B.: No features in text.
# Language detection error for https://www.youtube.com/watch?v=CTrEqJgytVA: No features in text.
# Language detection error for Vous aimez travailler en extérieur et n’avez pas peur de la hauteur ;: No features in text.
# Language detection error for Vous souhaitez réaliser votre année de Terminale Bac Pro MELEC, en alternance ;: No features in text.
# Language detection error for Vous avez déjà un CAP ou un Bac Pro en Électricité et vous souhaitez préparer un Titre Professionnel ou une Mention Complémentaire de Monteur de Réseaux Électriques Aéro-souterrains ;: No features in text.
# Language detection error for Vous possédez le permis B.: No features in text.
# Language detection error for https://www.youtube.com/watch?v=CTrEqJgytVA: No features in text.
# Language detection error for Vous aimez travailler en extérieur: No features in text.
# Language detection error for Vous avez la capacité à travailler en hauteur: No features in text.
# Language detection error for Vous avez des connaissances en électricité ou avez un diplôme en électricité: No features in text.
# Language detection error for Vous souhaitez préparer un Titre Professionnel Monteur de réseaux ou une Mention Complémentaire de Monteur de Réseaux Électriques aéro-souterrains: No features in text.
# Language detection error for Vous possédez le permis B.: No features in text.
# Language detection error for https://www.youtube.com/watch?v=CTrEqJgytVA: No features in text.
# Language detection error for Tu aimes travailler en extérieur et n’a pas peur de la hauteur ;: No features in text.
# Language detection error for Tu souhaites réaliser un Bac Pro MELEC ou toute autre formation en lien avec le métier.: No features in text.
# Language detection error for ?: No features in text.

# %%
job_df['level'].value_counts()
# Out:
# level
# Entry level         1151
# Mid-Senior level    1013
# Associate            989
# Internship           777
# Director             320
# Executive            153
# Not Applicable        95
# Name: count, dtype: int64

# %%
job_df['title'] = job_df['job_title'].apply(preprocessing)
job_df['job_function'] = job_df['job_function'].apply(preprocessing)
job_df['industries'] = job_df['industries'].apply(preprocessing)
job_df['text'] = job_df['title'] + " " + job_df['job_function'] + " " + job_df['industries']

# %%
job_df.to_csv('preprocessed/linkedin_jobs.csv', index=False)
